# %% [markdown]
# # 🎬 IMDb Top‑1000 Content‑Based Recommender
# This notebook builds a simple content‑based movie recommendation engine using **Overview** (plot summary) and **Genre** from the IMDb Top‑1000 Movies & TV dataset.
# **Steps**:
# 1. Load & inspect data
# 2. Clean and preprocess features
# 3. Vectorize overviews with TF‑IDF
# 4. One‑hot encode genres
# 5. Combine similarities and recommend movies
#
# > **Dataset**: download the CSV from Kaggle and place it next to this notebook as `imdb_top_1000.csv`.
# > **Libraries required**: `pandas`, `numpy`, `scikit‑learn`, `nltk`. Install with `pip install pandas numpy scikit-learn nltk` if needed.

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MultiLabelBinarizer
import re, nltk, string, warnings
warnings.filterwarnings('ignore')

# Make sure NLTK stopwords are downloaded once
nltk.download('stopwords', quiet=True)
from nltk.corpus import stopwords
STOPWORDS = set(stopwords.words('english'))

# %%
# ↳ CHANGE the path if your file lives elsewhere
df = pd.read_csv('imdb_top_1000.csv')
print(f"Loaded {df.shape[0]} rows and {df.shape[1]} columns")
df.head()
# Out:
# Loaded 1000 rows and 16 columns
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411
# 2   Michael Caine      2303232  534,858,444
# 3    Diane Keaton      1129952   57,300,000
# 4    John Fiedler       689845    4,360,000

# %%
def clean_overview(text):
    if pd.isna(text):
        return ""
    # lowercase
    text = text.lower()
    # remove html tags & punctuation
    text = re.sub('<.*?>', ' ', text)
    text = text.translate(str.maketrans('', '', string.punctuation))
    # tokenize & remove stop words
    tokens = [w for w in text.split() if w not in STOPWORDS]
    return ' '.join(tokens)

df['clean_overview'] = df['Overview'].apply(clean_overview)
df['clean_overview'].head()
# Out:
# 0    two imprisoned men bond number years finding s...
# 1    organized crime dynastys aging patriarch trans...
# 2    menace known joker wreaks havoc chaos people g...
# 3    early life career vito corleone 1920s new york...
# 4    jury holdout attempts prevent miscarriage just...
# Name: clean_overview, dtype: object

# %%
df['genre_list'] = df['Genre'].str.split(',\s*')
mlb = MultiLabelBinarizer()
genre_matrix = mlb.fit_transform(df['genre_list'])
genre_df = pd.DataFrame(genre_matrix, columns=mlb.classes_, index=df.index)
print(f"One‑hot genre matrix shape: {genre_df.shape}")
#print(genre_df.head())
# Out:
# One‑hot genre matrix shape: (1000, 21)

# %%
tfidf = TfidfVectorizer(max_features=5000)
overview_tfidf = tfidf.fit_transform(df['clean_overview'])
overview_tfidf
# Out:
# <1000x5000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 13487 stored elements in Compressed Sparse Row format>

# %%
# Show the TF-IDF vector for the first movie (as a dense array)
print("TF-IDF vector for the first movie:")
print(overview_tfidf[0].toarray()[0])

# Or, print the top 10 nonzero terms for the first movie
feature_names = tfidf.get_feature_names_out()
row = overview_tfidf[0].toarray()[0]
top_indices = row.argsort()[-10:][::-1]
print("\nTop 10 TF-IDF terms for the first movie:")
for idx in top_indices:
    if row[idx] > 0:
        print(f"{feature_names[idx]}: {row[idx]:.3f}")
# Out:
# TF-IDF vector for the first movie:
# [0. 0. 0. ... 0. 0. 0.]
#
# Top 10 TF-IDF terms for the first movie:
# decency: 0.352
# number: 0.333
# acts: 0.333
# solace: 0.333
# common: 0.319
# finding: 0.299
# redemption: 0.279
# imprisoned: 0.279
# bond: 0.274
# men: 0.231

# %%
# Cosine similarity on overviews (dense may be large; keep sparse CSR)
cosine_sim = cosine_similarity(overview_tfidf)

# Genre similarity – simple dot product / intersection count normalised
genre_sim = cosine_similarity(genre_matrix)

# Combine similarities (tune alpha) – here 80% text, 20% genre
alpha = 0.8
combined_sim = alpha * cosine_sim + (1 - alpha) * genre_sim
combined_sim[:5, :5]
# Out:
# array([[1.        , 0.14142136, 0.11547005, 0.14142136, 0.14142136],
#        [0.14142136, 1.        , 0.16329932, 0.26779516, 0.2       ],
#        [0.11547005, 0.16329932, 1.        , 0.16329932, 0.16329932],
#        [0.14142136, 0.26779516, 0.16329932, 1.        , 0.2       ],
#        [0.14142136, 0.2       , 0.16329932, 0.2       , 1.        ]])

# %%
print(df.columns.tolist())
# Out:
# ['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate', 'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director', 'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross', 'clean_overview', 'genre_list']

# %% [markdown]
# ### 🔍 Quick Demo
# Uncomment the last line in the previous cell and run it to see 10 recommendations for **"The Dark Knight"** (or choose any other title in the dataset).

# %%
def recommend(title, k=10):
    if title not in df['Series_Title'].values:
        raise ValueError(f"'{title}' not found in dataset.")
    idx = df.index[df['Series_Title'] == title][0]
    sim_scores = list(enumerate(combined_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    top_indices = [i for i, _ in sim_scores[1:k+1]]
    recs = df.iloc[top_indices][['Series_Title', 'Genre', 'IMDB_Rating']]
    return recs.reset_index(drop=True)

# Example usage
recommend('The Dark Knight')
# Out:
#           Series_Title                   Genre  IMDB_Rating
# 0    Kill Bill: Vol. 1    Action, Crime, Drama          8.1
# 1        Batman Begins       Action, Adventure          8.2
# 2                Joker  Crime, Drama, Thriller          8.5
# 3  Dip huet seung hung    Action, Crime, Drama          7.8
# 4         The Fugitive    Action, Crime, Drama          7.8
# 5  Lucky Number Slevin    Action, Crime, Drama          7.7
# 6                 Léon    Action, Crime, Drama          8.5
# 7         Vikram Vedha    Action, Crime, Drama          8.4
# 8               Haider    Action, Crime, Drama          8.1
# 9          A Wednesday    Action, Crime, Drama          8.1

# %% [markdown]
# ### Evaluation

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from collections import Counter

def calculate_genre_similarity(movie1_genres, movie2_genres):
    """Calculate Jaccard similarity between two movies' genres."""
    genres1 = set(movie1_genres.split(', '))
    genres2 = set(movie2_genres.split(', '))
    intersection = len(genres1.intersection(genres2))
    union = len(genres1.union(genres2))
    return intersection / union if union > 0 else 0

def evaluate_genre_consistency(df, recommendations, input_movie):
    """Evaluate how well the recommendations maintain genre consistency."""
    input_genres = df[df['Series_Title'] == input_movie]['Genre'].iloc[0]
    genre_similarities = []
    
    for _, rec in recommendations.iterrows():
        similarity = calculate_genre_similarity(input_genres, rec['Genre'])
        genre_similarities.append(similarity)
    
    return {
        'mean_genre_similarity': np.mean(genre_similarities),
        'min_genre_similarity': np.min(genre_similarities),
        'max_genre_similarity': np.max(genre_similarities)
    }

def evaluate_rating_distribution(df, recommendations, input_movie):
    """Evaluate the rating distribution of recommendations."""
    input_rating = df[df['Series_Title'] == input_movie]['IMDB_Rating'].iloc[0]
    rec_ratings = recommendations['IMDB_Rating'].values
    
    return {
        'input_movie_rating': input_rating,
        'mean_rec_rating': np.mean(rec_ratings),
        'std_rec_rating': np.std(rec_ratings),
        'min_rating': np.min(rec_ratings),
        'max_rating': np.max(rec_ratings),
        'rating_diff': abs(input_rating - np.mean(rec_ratings))
    }

def evaluate_diversity(recommendations):
    """Evaluate diversity in recommendations based on genres."""
    all_genres = []
    for genres in recommendations['Genre']:
        all_genres.extend(genres.split(', '))
    
    genre_counts = Counter(all_genres)
    unique_genres = len(genre_counts)
    genre_entropy = -sum((count/len(all_genres)) * np.log2(count/len(all_genres)) 
                        for count in genre_counts.values())
    
    return {
        'unique_genres': unique_genres,
        'genre_entropy': genre_entropy,
        'genre_distribution': dict(genre_counts)
    }

def comprehensive_evaluation(df, recommender_func, movie_title, k=10):
    """Run comprehensive evaluation for a given movie."""
    try:
        recommendations = recommender_func(movie_title, k)
        
        # Get all evaluation metrics
        genre_metrics = evaluate_genre_consistency(df, recommendations, movie_title)
        rating_metrics = evaluate_rating_distribution(df, recommendations, movie_title)
        diversity_metrics = evaluate_diversity(recommendations)
        
        # Combine all metrics
        evaluation_results = {
            'movie_title': movie_title,
            'num_recommendations': len(recommendations),
            **genre_metrics,
            **rating_metrics,
            **diversity_metrics
        }
        
        return evaluation_results, recommendations
        
    except Exception as e:
        return {'error': str(e)}, None

def evaluate_multiple_movies(df, recommender_func, num_samples=10, k=10):
    """Evaluate recommender system on multiple random movies."""
    sample_movies = df['Series_Title'].sample(n=num_samples).tolist()
    all_results = []
    
    for movie in sample_movies:
        results, _ = comprehensive_evaluation(df, recommender_func, movie, k)
        all_results.append(results)
    
    # Calculate aggregate statistics
    aggregate_metrics = pd.DataFrame(all_results).mean(numeric_only=True).to_dict()
    
    return {
        'individual_results': all_results,
        'aggregate_metrics': aggregate_metrics
    }

# %% [markdown]
# ### Save model

# %%
import pickle

# Create a dictionary with all the components needed for recommendations
model_components = {
    'tfidf_vectorizer': tfidf,
    'genre_binarizer': mlb,
    'combined_similarity': combined_sim,
    'movies_data': df[['Series_Title', 'Genre', 'IMDB_Rating', 'clean_overview', 'genre_list']]
}

# Save the model components
with open('movie_recommender_model.pkl', 'wb') as f:
    pickle.dump(model_components, f)

print("Model saved successfully as 'movie_recommender_model.pkl'")
# Out:
# Model saved successfully as 'movie_recommender_model.pkl'

# %% [markdown]
# ### To test if the model import is successful

# %%
# First make sure we have the loaded model function
if 'recommend_from_loaded_model' not in globals():
    # Load the saved model
    with open('movie_recommender_model.pkl', 'rb') as f:
        loaded_model = pickle.load(f)
    
    # Define the recommendation function using the loaded model
    def recommend_from_loaded_model(title, k=10):
        movies_df = loaded_model['movies_data']
        combined_sim = loaded_model['combined_similarity']
        
        if title not in movies_df['Series_Title'].values:
            raise ValueError(f"'{title}' not found in dataset.")
        
        idx = movies_df.index[movies_df['Series_Title'] == title][0]
        sim_scores = list(enumerate(combined_sim[idx]))
        sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
        top_indices = [i for i, _ in sim_scores[1:k+1]]
        
        recs = movies_df.iloc[top_indices][['Series_Title', 'Genre', 'IMDB_Rating']]
        return recs.reset_index(drop=True)

# Now compare the results
print("Original model recommendations:")
original_recommendations = recommend('The Dark Knight')
print(original_recommendations)

print("\nLoaded model recommendations:")
loaded_recommendations = recommend_from_loaded_model('The Dark Knight')
print(loaded_recommendations)

# Check if the recommendations are exactly the same
are_identical = original_recommendations.equals(loaded_recommendations)
print(f"\nAre the recommendations identical? {are_identical}")

if not are_identical:
    print("\nDifferences in recommendations:")
    # Compare the movie titles
    original_titles = set(original_recommendations['Series_Title'])
    loaded_titles = set(loaded_recommendations['Series_Title'])
    
    print("\nMovies only in original recommendations:")
    print(original_titles - loaded_titles)
    
    print("\nMovies only in loaded recommendations:")
    print(loaded_titles - original_titles)
# Out:
# Original model recommendations:
#           Series_Title                   Genre  IMDB_Rating
# 0    Kill Bill: Vol. 1    Action, Crime, Drama          8.1
# 1        Batman Begins       Action, Adventure          8.2
# 2                Joker  Crime, Drama, Thriller          8.5
# 3  Dip huet seung hung    Action, Crime, Drama          7.8
# 4         The Fugitive    Action, Crime, Drama          7.8
# 5  Lucky Number Slevin    Action, Crime, Drama          7.7
# 6                 Léon    Action, Crime, Drama          8.5
# 7         Vikram Vedha    Action, Crime, Drama          8.4
# 8               Haider    Action, Crime, Drama          8.1
# 9          A Wednesday    Action, Crime, Drama          8.1
#
# Loaded model recommendations:
#           Series_Title                   Genre  IMDB_Rating
# 0    Kill Bill: Vol. 1    Action, Crime, Drama          8.1
# 1        Batman Begins       Action, Adventure          8.2
# 2                Joker  Crime, Drama, Thriller          8.5
# 3  Dip huet seung hung    Action, Crime, Drama          7.8
# 4         The Fugitive    Action, Crime, Drama          7.8
# 5  Lucky Number Slevin    Action, Crime, Drama          7.7
# 6                 Léon    Action, Crime, Drama          8.5
# 7         Vikram Vedha    Action, Crime, Drama          8.4
# 8               Haider    Action, Crime, Drama          8.1
# 9          A Wednesday    Action, Crime, Drama          8.1
#
# Are the recommendations identical? True

# %% [markdown]
# ### Import model and test it

# %%
# Test the loaded model
import pickle

# Load the saved model
with open('movie_recommender_model.pkl', 'rb') as f:
    loaded_model = pickle.load(f)

# Create a recommendation function using the loaded model
def recommend_from_loaded_model(title, k=10):
    movies_df = loaded_model['movies_data']
    combined_sim = loaded_model['combined_similarity']
    
    if title not in movies_df['Series_Title'].values:
        raise ValueError(f"'{title}' not found in dataset.")
    
    idx = movies_df.index[movies_df['Series_Title'] == title][0]
    sim_scores = list(enumerate(combined_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    top_indices = [i for i, _ in sim_scores[1:k+1]]
    
    recs = movies_df.iloc[top_indices][['Series_Title', 'Genre', 'IMDB_Rating']]
    return recs.reset_index(drop=True)

# Test with a movie (let's use "The Dark Knight" as an example)
print("Testing recommendations using the loaded model:")
print("\nRecommendations for 'The Dark Knight':")
recommendations = recommend_from_loaded_model('The Dark Knight')
print(recommendations)

# %%
# --- Run a comprehensive evaluation on random sample of movies ---
num_samples = 1000  # You can change this to evaluate more/less movies
k = 10  # Number of recommendations per movie

results = evaluate_multiple_movies(df, recommend, num_samples=num_samples, k=k)

print("=== Aggregate Evaluation Metrics ===")
for key, value in results['aggregate_metrics'].items():
    print(f"{key}: {value}")

print("\n=== Individual Movie Evaluation Results ===")
for res in results['individual_results']:
    print(res)
# Out:
# === Aggregate Evaluation Metrics ===
# num_recommendations: 10.0
# mean_genre_similarity: 0.7377533333333334
# min_genre_similarity: 0.40848333333333336
# max_genre_similarity: 0.9656666666666667
# input_movie_rating: 7.9494
# mean_rec_rating: 7.98477
# std_rec_rating: 0.2625621493941213
# min_rating: 7.639199999999999
# max_rating: 8.479700000000001
# rating_diff: 0.23320999999999997
# unique_genres: 5.349
# genre_entropy: 1.8859751678530532
#
# === Individual Movie Evaluation Results ===
# {'movie_title': 'A Night at the Opera', 'num_recommendations': 10, 'mean_genre_similarity': 0.42833333333333323, 'min_genre_similarity': 0.2, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.9, 'mean_rec_rating': 7.860000000000001, 'std_rec_rating': 0.2059126028197399, 'min_rating': 7.6, 'max_rating': 8.2, 'rating_diff': 0.03999999999999915, 'unique_genres': 5, 'genre_entropy': 2.1312824845975875, 'genre_distribution': {'Comedy': 8, 'Music': 5, 'Musical': 2, 'Drama': 5, 'Romance': 2}}
# {'movie_title': 'Sherlock Jr.', 'num_recommendations': 10, 'mean_genre_similarity': 0.6333333333333334, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.2, 'mean_rec_rating': 8.09, 'std_rec_rating': 0.13747727084867525, 'min_rating': 7.9, 'max_rating': 8.3, 'rating_diff': 0.10999999999999943, 'unique_genres': 7, 'genre_entropy': 2.164889451733241, 'genre_distribution': {'Comedy': 10, 'Romance': 8, 'Action': 3, 'Adventure': 1, 'Crime': 1, 'Musical': 1, 'Drama': 1}}
# {'movie_title': 'Vampire Hunter D: Bloodlust', 'num_recommendations': 10, 'mean_genre_similarity': 0.31, 'min_genre_similarity': 0.0, 'max_genre_similarity': 0.5, 'input_movie_rating': 7.7, 'mean_rec_rating': 8.1, 'std_rec_rating': 0.27568097504180433, 'min_rating': 7.7, 'max_rating': 8.7, 'rating_diff': 0.39999999999999947, 'unique_genres': 9, 'genre_entropy': 2.9076910954624604, 'genre_distribution': {'Action': 5, 'Adventure': 6, 'Fantasy': 4, 'Animation': 4, 'Family': 1, 'Horror': 1, 'Drama': 3, 'Comedy': 2, 'Western': 1}}
# {'movie_title': 'Zulu', 'num_recommendations': 10, 'mean_genre_similarity': 0.8, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.7, 'mean_rec_rating': 7.959999999999999, 'std_rec_rating': 0.3039736830714133, 'min_rating': 7.6, 'max_rating': 8.6, 'rating_diff': 0.2599999999999989, 'unique_genres': 5, 'genre_entropy': 1.9137714102981038, 'genre_distribution': {'Action': 1, 'Drama': 9, 'History': 7, 'War': 9, 'Adventure': 1}}
# {'movie_title': 'Toy Story', 'num_recommendations': 10, 'mean_genre_similarity': 1.0, 'min_genre_similarity': 1.0, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.3, 'mean_rec_rating': 8.059999999999999, 'std_rec_rating': 0.13564659966250506, 'min_rating': 7.8, 'max_rating': 8.2, 'rating_diff': 0.240000000000002, 'unique_genres': 3, 'genre_entropy': 1.584962500721156, 'genre_distribution': {'Animation': 10, 'Adventure': 10, 'Comedy': 10}}
# {'movie_title': 'Taare Zameen Par', 'num_recommendations': 10, 'mean_genre_similarity': 0.4833333333333333, 'min_genre_similarity': 0.25, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.4, 'mean_rec_rating': 7.88, 'std_rec_rating': 0.22715633383201106, 'min_rating': 7.6, 'max_rating': 8.3, 'rating_diff': 0.5200000000000005, 'unique_genres': 6, 'genre_entropy': 2.180337381067571, 'genre_distribution': {'Drama': 9, 'Family': 3, 'Comedy': 2, 'Sport': 1, 'Crime': 2, 'Mystery': 2}}
# {'movie_title': 'Ba wang bie ji', 'num_recommendations': 10, 'mean_genre_similarity': 0.6666666666666666, 'min_genre_similarity': 0.3333333333333333, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.1, 'mean_rec_rating': 7.889999999999999, 'std_rec_rating': 0.27367864366808026, 'min_rating': 7.6, 'max_rating': 8.5, 'rating_diff': 0.21000000000000085, 'unique_genres': 5, 'genre_entropy': 1.8290328929684438, 'genre_distribution': {'Drama': 10, 'Romance': 8, 'Music': 3, 'Mystery': 1, 'Comedy': 1}}
# {'movie_title': 'Fa yeung nin wah', 'num_recommendations': 10, 'mean_genre_similarity': 0.8833333333333332, 'min_genre_similarity': 0.3333333333333333, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.1, 'mean_rec_rating': 8.010000000000002, 'std_rec_rating': 0.4548626166217665, 'min_rating': 7.7, 'max_rating': 9.3, 'rating_diff': 0.08999999999999808, 'unique_genres': 3, 'genre_entropy': 1.2363864108712894, 'genre_distribution': {'Comedy': 1, 'Drama': 10, 'Romance': 8}}
# {'movie_title': 'To Be or Not to Be', 'num_recommendations': 10, 'mean_genre_similarity': 0.5416666666666667, 'min_genre_similarity': 0.25, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.2, 'mean_rec_rating': 7.970000000000001, 'std_rec_rating': 0.2609597670139979, 'min_rating': 7.6, 'max_rating': 8.4, 'rating_diff': 0.22999999999999865, 'unique_genres': 6, 'genre_entropy': 2.2214130664659364, 'genre_distribution': {'Adventure': 3, 'Comedy': 8, 'War': 8, 'Drama': 7, 'Romance': 1, 'Action': 1}}
# {'movie_title': 'This Is England', 'num_recommendations': 10, 'mean_genre_similarity': 0.7166666666666667, 'min_genre_similarity': 0.3333333333333333, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.7, 'mean_rec_rating': 8.01, 'std_rec_rating': 0.2699999999999999, 'min_rating': 7.6, 'max_rating': 8.6, 'rating_diff': 0.3099999999999996, 'unique_genres': 7, 'genre_entropy': 2.05621500939744, 'genre_distribution': {'Crime': 7, 'Drama': 10, 'Mystery': 1, 'Adventure': 1, 'Musical': 1, 'Comedy': 1, 'Action': 1}}
# {'movie_title': 'Scarface', 'num_recommendations': 10, 'mean_genre_similarity': 0.7, 'min_genre_similarity': 0.6666666666666666, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.3, 'mean_rec_rating': 7.88, 'std_rec_rating': 0.19390719429665298, 'min_rating': 7.6, 'max_rating': 8.2, 'rating_diff': 0.4200000000000008, 'unique_genres': 6, 'genre_entropy': 2.1271723951306507, 'genre_distribution': {'Crime': 10, 'Drama': 10, 'Biography': 3, 'Action': 4, 'Thriller': 1, 'Mystery': 1}}
# {'movie_title': 'Watchmen', 'num_recommendations': 10, 'mean_genre_similarity': 0.7, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.6, 'mean_rec_rating': 8.03, 'std_rec_rating': 0.31320919526731655, 'min_rating': 7.6, 'max_rating': 8.6, 'rating_diff': 0.4299999999999997, 'unique_genres': 9, 'genre_entropy': 2.4825887305018335, 'genre_distribution': {'Action': 6, 'Drama': 10, 'Mystery': 8, 'Sport': 1, 'Thriller': 1, 'Crime': 1, 'War': 1, 'Romance': 1, 'Sci-Fi': 1}}
# {'movie_title': 'Requiem for a Dream', 'num_recommendations': 10, 'mean_genre_similarity': 0.8333333333333333, 'min_genre_similarity': 0.3333333333333333, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.3, 'mean_rec_rating': 8.2, 'std_rec_rating': 0.507937003968012, 'min_rating': 7.6, 'max_rating': 9.3, 'rating_diff': 0.10000000000000142, 'unique_genres': 4, 'genre_entropy': 1.2916919971380594, 'genre_distribution': {'Drama': 10, 'Crime': 1, 'Mystery': 1, 'Romance': 2}}
# {'movie_title': 'The Dark Knight', 'num_recommendations': 10, 'mean_genre_similarity': 0.875, 'min_genre_similarity': 0.25, 'max_genre_similarity': 1.0, 'input_movie_rating': 9.0, 'mean_rec_rating': 8.12, 'std_rec_rating': 0.27495454169735045, 'min_rating': 7.7, 'max_rating': 8.5, 'rating_diff': 0.8800000000000008, 'unique_genres': 5, 'genre_entropy': 1.9066715110261088, 'genre_distribution': {'Action': 9, 'Crime': 9, 'Drama': 9, 'Adventure': 1, 'Thriller': 1}}
# {'movie_title': 'Lawrence of Arabia', 'num_recommendations': 10, 'mean_genre_similarity': 0.725, 'min_genre_similarity': 0.25, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.3, 'mean_rec_rating': 7.92, 'std_rec_rating': 0.15999999999999992, 'min_rating': 7.6, 'max_rating': 8.2, 'rating_diff': 0.3800000000000008, 'unique_genres': 7, 'genre_entropy': 2.288248241414466, 'genre_distribution': {'Adventure': 7, 'Biography': 7, 'Drama': 10, 'Action': 1, 'Thriller': 1, 'Crime': 2, 'History': 1}}
# {'movie_title': 'Kurenai no buta', 'num_recommendations': 10, 'mean_genre_similarity': 0.8033333333333333, 'min_genre_similarity': 0.2, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.7, 'mean_rec_rating': 7.960000000000001, 'std_rec_rating': 0.23323807579381187, 'min_rating': 7.7, 'max_rating': 8.3, 'rating_diff': 0.2600000000000007, 'unique_genres': 6, 'genre_entropy': 2.074164743022575, 'genre_distribution': {'Animation': 8, 'Adventure': 8, 'Comedy': 9, 'Crime': 1, 'Biography': 1, 'Drama': 1}}
# {'movie_title': 'The Pianist', 'num_recommendations': 10, 'mean_genre_similarity': 0.45999999999999996, 'min_genre_similarity': 0.2, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.5, 'mean_rec_rating': 8.02, 'std_rec_rating': 0.3736308338453881, 'min_rating': 7.7, 'max_rating': 8.9, 'rating_diff': 0.4800000000000004, 'unique_genres': 9, 'genre_entropy': 2.765596230357602, 'genre_distribution': {'Action': 1, 'Drama': 10, 'History': 3, 'Animation': 2, 'War': 3, 'Biography': 6, 'Music': 2, 'Thriller': 2, 'Mystery': 1}}
# {'movie_title': 'To Kill a Mockingbird', 'num_recommendations': 10, 'mean_genre_similarity': 0.7333333333333333, 'min_genre_similarity': 0.3333333333333333, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.2, 'mean_rec_rating': 7.989999999999999, 'std_rec_rating': 0.3360059523282288, 'min_rating': 7.6, 'max_rating': 8.6, 'rating_diff': 0.20999999999999996, 'unique_genres': 6, 'genre_entropy': 2.094724104223614, 'genre_distribution': {'Crime': 9, 'Drama': 10, 'Fantasy': 1, 'Thriller': 2, 'Mystery': 2, 'Action': 2}}
# {'movie_title': 'The Intouchables', 'num_recommendations': 10, 'mean_genre_similarity': 0.8166666666666667, 'min_genre_similarity': 0.3333333333333333, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.5, 'mean_rec_rating': 7.790000000000001, 'std_rec_rating': 0.17578395831246935, 'min_rating': 7.6, 'max_rating': 8.2, 'rating_diff': 0.7099999999999991, 'unique_genres': 4, 'genre_entropy': 1.7289635271341162, 'genre_distribution': {'Biography': 6, 'Comedy': 9, 'Drama': 10, 'Romance': 1}}
# {'movie_title': "La leggenda del pianista sull'oceano", 'num_recommendations': 10, 'mean_genre_similarity': 0.8333333333333333, 'min_genre_similarity': 0.3333333333333333, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.1, 'mean_rec_rating': 7.87, 'std_rec_rating': 0.17916472867168912, 'min_rating': 7.6, 'max_rating': 8.1, 'rating_diff': 0.22999999999999954, 'unique_genres': 3, 'genre_entropy': 1.5690255736436503, 'genre_distribution': {'Drama': 10, 'Music': 7, 'Romance': 8}}
# {'movie_title': 'Blowup', 'num_recommendations': 10, 'mean_genre_similarity': 0.575, 'min_genre_similarity': 0.25, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.6, 'mean_rec_rating': 8.14, 'std_rec_rating': 0.27640549922170504, 'min_rating': 7.7, 'max_rating': 8.6, 'rating_diff': 0.5400000000000009, 'unique_genres': 8, 'genre_entropy': 2.4831804684586087, 'genre_distribution': {'Drama': 9, 'Mystery': 5, 'Thriller': 6, 'Crime': 2, 'Adventure': 1, 'Comedy': 1, 'Music': 1, 'Horror': 1}}
# {'movie_title': 'The Lord of the Rings: The Fellowship of the Ring', 'num_recommendations': 10, 'mean_genre_similarity': 0.7, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.8, 'mean_rec_rating': 8.120000000000001, 'std_rec_rating': 0.43312815655415443, 'min_rating': 7.6, 'max_rating': 8.9, 'rating_diff': 0.6799999999999997, 'unique_genres': 6, 'genre_entropy': 2.168506245800977, 'genre_distribution': {'Adventure': 9, 'Drama': 7, 'Fantasy': 2, 'Action': 7, 'Family': 1, 'Animation': 1}}
# {'movie_title': 'JFK', 'num_recommendations': 10, 'mean_genre_similarity': 0.57, 'min_genre_similarity': 0.2, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.0, 'mean_rec_rating': 7.869999999999999, 'std_rec_rating': 0.2147091055358391, 'min_rating': 7.6, 'max_rating': 8.3, 'rating_diff': 0.13000000000000078, 'unique_genres': 7, 'genre_entropy': 2.3454372523105547, 'genre_distribution': {'Action': 1, 'Mystery': 1, 'Thriller': 5, 'Drama': 9, 'History': 5, 'Biography': 2, 'Comedy': 1}}
# {'movie_title': 'Chung Hing sam lam', 'num_recommendations': 10, 'mean_genre_similarity': 0.7333333333333333, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.1, 'mean_rec_rating': 7.9799999999999995, 'std_rec_rating': 0.18330302779823357, 'min_rating': 7.7, 'max_rating': 8.3, 'rating_diff': 0.1200000000000001, 'unique_genres': 7, 'genre_entropy': 2.209888638014727, 'genre_distribution': {'Comedy': 8, 'Crime': 6, 'Drama': 10, 'Mystery': 1, 'Music': 1, 'Fantasy': 1, 'Romance': 1}}
# {'movie_title': 'Blazing Saddles', 'num_recommendations': 10, 'mean_genre_similarity': 0.375, 'min_genre_similarity': 0.25, 'max_genre_similarity': 0.5, 'input_movie_rating': 7.7, 'mean_rec_rating': 8.08, 'std_rec_rating': 0.3682390527904396, 'min_rating': 7.6, 'max_rating': 8.8, 'rating_diff': 0.3799999999999999, 'unique_genres': 6, 'genre_entropy': 2.3095632280061937, 'genre_distribution': {'Western': 5, 'Drama': 5, 'Comedy': 5, 'Romance': 2, 'Crime': 1, 'Action': 1}}
# {'movie_title': "Jeux d'enfants", 'num_recommendations': 10, 'mean_genre_similarity': 0.8, 'min_genre_similarity': 0.6666666666666666, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.6, 'mean_rec_rating': 7.929999999999998, 'std_rec_rating': 0.19519221295943132, 'min_rating': 7.6, 'max_rating': 8.1, 'rating_diff': 0.3299999999999983, 'unique_genres': 3, 'genre_entropy': 1.5774287729134877, 'genre_distribution': {'Comedy': 8, 'Drama': 9, 'Romance': 7}}
# {'movie_title': 'Star Wars: Episode VII - The Force Awakens', 'num_recommendations': 10, 'mean_genre_similarity': 0.9, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.9, 'mean_rec_rating': 8.000000000000002, 'std_rec_rating': 0.272029410174709, 'min_rating': 7.7, 'max_rating': 8.4, 'rating_diff': 0.10000000000000142, 'unique_genres': 5, 'genre_entropy': 1.8922718656836104, 'genre_distribution': {'Action': 10, 'Adventure': 10, 'Sci-Fi': 8, 'Animation': 1, 'Fantasy': 1}}
# {'movie_title': 'Red River', 'num_recommendations': 10, 'mean_genre_similarity': 1.0, 'min_genre_similarity': 1.0, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.8, 'mean_rec_rating': 8.32, 'std_rec_rating': 0.43543082114154497, 'min_rating': 7.6, 'max_rating': 8.9, 'rating_diff': 0.5200000000000005, 'unique_genres': 3, 'genre_entropy': 1.584962500721156, 'genre_distribution': {'Action': 10, 'Adventure': 10, 'Drama': 10}}
# {'movie_title': 'Le notti di Cabiria', 'num_recommendations': 10, 'mean_genre_similarity': 0.85, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.1, 'mean_rec_rating': 7.889999999999999, 'std_rec_rating': 0.23000000000000012, 'min_rating': 7.6, 'max_rating': 8.3, 'rating_diff': 0.21000000000000085, 'unique_genres': 3, 'genre_entropy': 0.9912642605354288, 'genre_distribution': {'Drama': 10, 'Romance': 2, 'Comedy': 1}}
# {'movie_title': 'O Brother, Where Art Thou?', 'num_recommendations': 10, 'mean_genre_similarity': 0.49000000000000005, 'min_genre_similarity': 0.2, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.7, 'mean_rec_rating': 7.910000000000001, 'std_rec_rating': 0.2118962010041707, 'min_rating': 7.6, 'max_rating': 8.2, 'rating_diff': 0.21000000000000085, 'unique_genres': 8, 'genre_entropy': 2.6389205950315935, 'genre_distribution': {'Action': 3, 'Adventure': 9, 'Drama': 2, 'Animation': 3, 'Comedy': 8, 'Family': 2, 'Crime': 2, 'War': 1}}
# {'movie_title': 'PK', 'num_recommendations': 10, 'mean_genre_similarity': 0.5166666666666666, 'min_genre_similarity': 0.25, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.1, 'mean_rec_rating': 8.01, 'std_rec_rating': 0.20712315177207982, 'min_rating': 7.6, 'max_rating': 8.3, 'rating_diff': 0.08999999999999986, 'unique_genres': 7, 'genre_entropy': 2.3523037954930768, 'genre_distribution': {'Drama': 10, 'Sci-Fi': 2, 'Comedy': 5, 'Musical': 3, 'Romance': 2, 'Thriller': 1, 'Adventure': 1}}
# {'movie_title': 'The Bridges of Madison County', 'num_recommendations': 10, 'mean_genre_similarity': 0.8166666666666667, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.6, 'mean_rec_rating': 8.030000000000001, 'std_rec_rating': 0.32878564445547215, 'min_rating': 7.7, 'max_rating': 8.8, 'rating_diff': 0.4300000000000015, 'unique_genres': 3, 'genre_entropy': 1.2326602568158205, 'genre_distribution': {'Drama': 10, 'Romance': 7, 'Crime': 1}}
# {'movie_title': 'American Psycho', 'num_recommendations': 10, 'mean_genre_similarity': 0.5666666666666667, 'min_genre_similarity': 0.3333333333333333, 'max_genre_similarity': 0.6666666666666666, 'input_movie_rating': 7.6, 'mean_rec_rating': 8.089999999999998, 'std_rec_rating': 0.37000000000000005, 'min_rating': 7.6, 'max_rating': 9.0, 'rating_diff': 0.48999999999999844, 'unique_genres': 3, 'genre_entropy': 1.2210477851797181, 'genre_distribution': {'Crime': 6, 'Drama': 10, 'Comedy': 1}}
# {'movie_title': 'Days of Heaven', 'num_recommendations': 10, 'mean_genre_similarity': 0.9333333333333332, 'min_genre_similarity': 0.6666666666666666, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.8, 'mean_rec_rating': 7.88, 'std_rec_rating': 0.15999999999999998, 'min_rating': 7.6, 'max_rating': 8.1, 'rating_diff': 0.08000000000000007, 'unique_genres': 4, 'genre_entropy': 1.4394969869215133, 'genre_distribution': {'Drama': 10, 'Romance': 10, 'Music': 1, 'Comedy': 1}}
# {'movie_title': 'Underground', 'num_recommendations': 10, 'mean_genre_similarity': 0.7166666666666667, 'min_genre_similarity': 0.3333333333333333, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.1, 'mean_rec_rating': 8.05, 'std_rec_rating': 0.2499999999999999, 'min_rating': 7.7, 'max_rating': 8.6, 'rating_diff': 0.049999999999998934, 'unique_genres': 4, 'genre_entropy': 1.7544061094608834, 'genre_distribution': {'Comedy': 7, 'Drama': 9, 'War': 6, 'Romance': 1}}
# {'movie_title': 'Marriage Story', 'num_recommendations': 10, 'mean_genre_similarity': 0.7666666666666666, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.9, 'mean_rec_rating': 8.149999999999999, 'std_rec_rating': 0.25396850198400583, 'min_rating': 7.7, 'max_rating': 8.6, 'rating_diff': 0.24999999999999822, 'unique_genres': 5, 'genre_entropy': 1.8789687013606593, 'genre_distribution': {'Adventure': 1, 'Comedy': 5, 'Drama': 10, 'Romance': 9, 'Biography': 1}}
# {'movie_title': 'Toy Story 2', 'num_recommendations': 10, 'mean_genre_similarity': 0.95, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.9, 'mean_rec_rating': 8.0, 'std_rec_rating': 0.23237900077244494, 'min_rating': 7.6, 'max_rating': 8.3, 'rating_diff': 0.09999999999999964, 'unique_genres': 4, 'genre_entropy': 1.7412943652509165, 'genre_distribution': {'Animation': 9, 'Adventure': 10, 'Comedy': 10, 'Drama': 1}}
# {'movie_title': 'Huo Yuan Jia', 'num_recommendations': 10, 'mean_genre_similarity': 0.85, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.6, 'mean_rec_rating': 8.080000000000002, 'std_rec_rating': 0.2181742422927143, 'min_rating': 7.6, 'max_rating': 8.4, 'rating_diff': 0.4800000000000022, 'unique_genres': 4, 'genre_entropy': 1.7400693385983697, 'genre_distribution': {'Action': 9, 'Biography': 7, 'Drama': 10, 'Sport': 1}}
# {'movie_title': 'Veer-Zaara', 'num_recommendations': 10, 'mean_genre_similarity': 0.575, 'min_genre_similarity': 0.25, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.8, 'mean_rec_rating': 7.93, 'std_rec_rating': 0.214709105535839, 'min_rating': 7.6, 'max_rating': 8.4, 'rating_diff': 0.1299999999999999, 'unique_genres': 7, 'genre_entropy': 2.273622566411168, 'genre_distribution': {'Comedy': 1, 'Drama': 9, 'Musical': 5, 'Animation': 1, 'Family': 5, 'Music': 1, 'Sci-Fi': 1}}
# {'movie_title': 'The Man Who Would Be King', 'num_recommendations': 10, 'mean_genre_similarity': 0.38500000000000006, 'min_genre_similarity': 0.2, 'max_genre_similarity': 0.5, 'input_movie_rating': 7.8, 'mean_rec_rating': 7.880000000000001, 'std_rec_rating': 0.19899748742132414, 'min_rating': 7.6, 'max_rating': 8.3, 'rating_diff': 0.08000000000000096, 'unique_genres': 7, 'genre_entropy': 2.5126012561274513, 'genre_distribution': {'Drama': 8, 'History': 5, 'War': 7, 'Adventure': 4, 'Comedy': 3, 'Action': 1, 'Animation': 1}}
# {'movie_title': "Miller's Crossing", 'num_recommendations': 10, 'mean_genre_similarity': 0.8333333333333333, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.7, 'mean_rec_rating': 8.08, 'std_rec_rating': 0.292574776766556, 'min_rating': 7.6, 'max_rating': 8.5, 'rating_diff': 0.3799999999999999, 'unique_genres': 5, 'genre_entropy': 1.9002088357626876, 'genre_distribution': {'Crime': 10, 'Drama': 9, 'Thriller': 7, 'Action': 1, 'Mystery': 1}}
# {'movie_title': 'Dil Chahta Hai', 'num_recommendations': 10, 'mean_genre_similarity': 0.8, 'min_genre_similarity': 0.3333333333333333, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.1, 'mean_rec_rating': 7.9799999999999995, 'std_rec_rating': 0.24819347291981705, 'min_rating': 7.6, 'max_rating': 8.5, 'rating_diff': 0.1200000000000001, 'unique_genres': 3, 'genre_entropy': 1.563202089984486, 'genre_distribution': {'Drama': 10, 'Comedy': 7, 'Romance': 7}}
# {'movie_title': 'Jûbê ninpûchô', 'num_recommendations': 10, 'mean_genre_similarity': 1.0, 'min_genre_similarity': 1.0, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.9, 'mean_rec_rating': 7.960000000000001, 'std_rec_rating': 0.26153393661244057, 'min_rating': 7.6, 'max_rating': 8.4, 'rating_diff': 0.0600000000000005, 'unique_genres': 3, 'genre_entropy': 1.584962500721156, 'genre_distribution': {'Animation': 10, 'Action': 10, 'Adventure': 10}}
# {'movie_title': 'Get Out', 'num_recommendations': 10, 'mean_genre_similarity': 0.7666666666666667, 'min_genre_similarity': 0.6666666666666666, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.7, 'mean_rec_rating': 8.03, 'std_rec_rating': 0.32572994949804673, 'min_rating': 7.6, 'max_rating': 8.5, 'rating_diff': 0.3299999999999992, 'unique_genres': 3, 'genre_entropy': 1.4281945908435036, 'genre_distribution': {'Horror': 3, 'Mystery': 10, 'Thriller': 10}}
# {'movie_title': 'The Odd Couple', 'num_recommendations': 10, 'mean_genre_similarity': 0.7166666666666666, 'min_genre_similarity': 0.3333333333333333, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.7, 'mean_rec_rating': 7.81, 'std_rec_rating': 0.18138357147217046, 'min_rating': 7.6, 'max_rating': 8.1, 'rating_diff': 0.10999999999999943, 'unique_genres': 5, 'genre_entropy': 1.7360411676599226, 'genre_distribution': {'Comedy': 10, 'Drama': 3, 'Romance': 2, 'Fantasy': 1, 'Crime': 1}}
# {'movie_title': 'Where Eagles Dare', 'num_recommendations': 10, 'mean_genre_similarity': 0.5233333333333333, 'min_genre_similarity': 0.2, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.7, 'mean_rec_rating': 8.07, 'std_rec_rating': 0.27586228448267447, 'min_rating': 7.6, 'max_rating': 8.5, 'rating_diff': 0.3700000000000001, 'unique_genres': 9, 'genre_entropy': 2.63108003028805, 'genre_distribution': {'Biography': 1, 'Drama': 4, 'War': 3, 'Action': 7, 'Adventure': 9, 'Animation': 1, 'Sci-Fi': 1, 'Crime': 1, 'Fantasy': 1}}
# {'movie_title': 'Wonder', 'num_recommendations': 10, 'mean_genre_similarity': 0.6, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.0, 'mean_rec_rating': 8.01, 'std_rec_rating': 0.2586503431275515, 'min_rating': 7.6, 'max_rating': 8.4, 'rating_diff': 0.009999999999999787, 'unique_genres': 5, 'genre_entropy': 1.6627992560224794, 'genre_distribution': {'Drama': 10, 'Family': 4, 'Sport': 1, 'Biography': 1, 'Animation': 1}}
# {'movie_title': 'Ondskan', 'num_recommendations': 10, 'mean_genre_similarity': 0.85, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.8, 'mean_rec_rating': 8.01, 'std_rec_rating': 0.21189620100417078, 'min_rating': 7.7, 'max_rating': 8.5, 'rating_diff': 0.20999999999999996, 'unique_genres': 4, 'genre_entropy': 1.1451104143815827, 'genre_distribution': {'Drama': 10, 'Comedy': 1, 'Music': 1, 'War': 1}}
# {'movie_title': 'Kingsman: The Secret Service', 'num_recommendations': 10, 'mean_genre_similarity': 0.9166666666666666, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.7, 'mean_rec_rating': 8.06, 'std_rec_rating': 0.2289104628451917, 'min_rating': 7.7, 'max_rating': 8.6, 'rating_diff': 0.3600000000000003, 'unique_genres': 4, 'genre_entropy': 1.7394098952052532, 'genre_distribution': {'Action': 10, 'Adventure': 10, 'Drama': 1, 'Comedy': 8}}
# {'movie_title': 'High Noon', 'num_recommendations': 10, 'mean_genre_similarity': 0.55, 'min_genre_similarity': 0.3333333333333333, 'max_genre_similarity': 0.6666666666666666, 'input_movie_rating': 7.9, 'mean_rec_rating': 7.989999999999999, 'std_rec_rating': 0.2981610303175116, 'min_rating': 7.6, 'max_rating': 8.5, 'rating_diff': 0.08999999999999897, 'unique_genres': 5, 'genre_entropy': 2.04597512699001, 'genre_distribution': {'Drama': 9, 'Western': 3, 'Crime': 4, 'Thriller': 7, 'Action': 1}}
# {'movie_title': 'The Last Picture Show', 'num_recommendations': 10, 'mean_genre_similarity': 0.9333333333333332, 'min_genre_similarity': 0.6666666666666666, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.0, 'mean_rec_rating': 8.11, 'std_rec_rating': 0.3477067730142744, 'min_rating': 7.6, 'max_rating': 8.8, 'rating_diff': 0.10999999999999943, 'unique_genres': 4, 'genre_entropy': 1.4394969869215133, 'genre_distribution': {'Drama': 10, 'Romance': 10, 'Music': 1, 'Comedy': 1}}
# {'movie_title': 'Back to the Future', 'num_recommendations': 10, 'mean_genre_similarity': 0.5666666666666667, 'min_genre_similarity': 0.3333333333333333, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.5, 'mean_rec_rating': 7.83, 'std_rec_rating': 0.13453624047073712, 'min_rating': 7.6, 'max_rating': 8.1, 'rating_diff': 0.6699999999999999, 'unique_genres': 6, 'genre_entropy': 2.2673195285703214, 'genre_distribution': {'Adventure': 8, 'Comedy': 7, 'Sci-Fi': 5, 'Action': 4, 'Crime': 1, 'Family': 1}}
# {'movie_title': 'La La Land', 'num_recommendations': 10, 'mean_genre_similarity': 0.5916666666666666, 'min_genre_similarity': 0.25, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.0, 'mean_rec_rating': 7.93, 'std_rec_rating': 0.2238302928559939, 'min_rating': 7.6, 'max_rating': 8.3, 'rating_diff': 0.07000000000000028, 'unique_genres': 5, 'genre_entropy': 2.1044984515601635, 'genre_distribution': {'Comedy': 6, 'Drama': 10, 'Music': 4, 'Romance': 2, 'Crime': 3}}
# {'movie_title': 'Le passé', 'num_recommendations': 10, 'mean_genre_similarity': 0.575, 'min_genre_similarity': 0.25, 'max_genre_similarity': 0.6666666666666666, 'input_movie_rating': 7.8, 'mean_rec_rating': 7.92, 'std_rec_rating': 0.1833030277982335, 'min_rating': 7.6, 'max_rating': 8.2, 'rating_diff': 0.1200000000000001, 'unique_genres': 8, 'genre_entropy': 2.387918502671133, 'genre_distribution': {'Drama': 10, 'Mystery': 6, 'Romance': 2, 'Music': 1, 'Crime': 2, 'Thriller': 1, 'Film-Noir': 1, 'Biography': 1}}
# {'movie_title': 'South Park: Bigger, Longer & Uncut', 'num_recommendations': 10, 'mean_genre_similarity': 0.445, 'min_genre_similarity': 0.2, 'max_genre_similarity': 0.5, 'input_movie_rating': 7.7, 'mean_rec_rating': 7.9, 'std_rec_rating': 0.20493901531919204, 'min_rating': 7.7, 'max_rating': 8.4, 'rating_diff': 0.20000000000000018, 'unique_genres': 7, 'genre_entropy': 2.4992352022341917, 'genre_distribution': {'Comedy': 9, 'Drama': 3, 'Fantasy': 4, 'Romance': 1, 'Animation': 5, 'Adventure': 6, 'Family': 1}}
# {'movie_title': 'Det sjunde inseglet', 'num_recommendations': 10, 'mean_genre_similarity': 0.4416666666666666, 'min_genre_similarity': 0.25, 'max_genre_similarity': 0.5, 'input_movie_rating': 8.2, 'mean_rec_rating': 7.9399999999999995, 'std_rec_rating': 0.2939387691339812, 'min_rating': 7.6, 'max_rating': 8.6, 'rating_diff': 0.2599999999999998, 'unique_genres': 8, 'genre_entropy': 2.5306993328423073, 'genre_distribution': {'Crime': 2, 'Drama': 10, 'Fantasy': 5, 'Comedy': 1, 'Biography': 2, 'History': 2, 'Romance': 2, 'Adventure': 1}}
# {'movie_title': "La passion de Jeanne d'Arc", 'num_recommendations': 10, 'mean_genre_similarity': 0.95, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.1, 'mean_rec_rating': 8.27, 'std_rec_rating': 0.30347981810987046, 'min_rating': 7.8, 'max_rating': 8.9, 'rating_diff': 0.16999999999999993, 'unique_genres': 4, 'genre_entropy': 1.7412943652509165, 'genre_distribution': {'Biography': 9, 'Drama': 10, 'History': 10, 'Thriller': 1}}
# {'movie_title': 'The Notebook', 'num_recommendations': 10, 'mean_genre_similarity': 0.9333333333333332, 'min_genre_similarity': 0.6666666666666666, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.8, 'mean_rec_rating': 7.81, 'std_rec_rating': 0.13, 'min_rating': 7.6, 'max_rating': 8.1, 'rating_diff': 0.009999999999999787, 'unique_genres': 3, 'genre_entropy': 1.3485878960124222, 'genre_distribution': {'Comedy': 2, 'Drama': 10, 'Romance': 10}}
# {'movie_title': 'Out of the Past', 'num_recommendations': 10, 'mean_genre_similarity': 0.7, 'min_genre_similarity': 0.3333333333333333, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.0, 'mean_rec_rating': 8.02, 'std_rec_rating': 0.21354156504062632, 'min_rating': 7.7, 'max_rating': 8.4, 'rating_diff': 0.019999999999999574, 'unique_genres': 5, 'genre_entropy': 1.898278922483087, 'genre_distribution': {'Crime': 7, 'Drama': 10, 'Film-Noir': 5, 'Action': 1, 'Mystery': 1}}
# {'movie_title': 'Der Untergang', 'num_recommendations': 10, 'mean_genre_similarity': 0.9199999999999999, 'min_genre_similarity': 0.2, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.2, 'mean_rec_rating': 8.239999999999998, 'std_rec_rating': 0.3352610922848043, 'min_rating': 7.7, 'max_rating': 8.9, 'rating_diff': 0.03999999999999915, 'unique_genres': 5, 'genre_entropy': 1.897626229780677, 'genre_distribution': {'Biography': 10, 'Drama': 9, 'History': 9, 'Animation': 1, 'Crime': 1}}
# {'movie_title': 'Kai po che!', 'num_recommendations': 10, 'mean_genre_similarity': 0.7416666666666667, 'min_genre_similarity': 0.25, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.7, 'mean_rec_rating': 7.919999999999999, 'std_rec_rating': 0.1777638883463117, 'min_rating': 7.6, 'max_rating': 8.1, 'rating_diff': 0.21999999999999886, 'unique_genres': 6, 'genre_entropy': 1.9653059184883495, 'genre_distribution': {'Comedy': 1, 'Drama': 10, 'Biography': 2, 'Sport': 7, 'Adventure': 1, 'Musical': 1}}
# {'movie_title': 'Barfi!', 'num_recommendations': 10, 'mean_genre_similarity': 0.9333333333333332, 'min_genre_similarity': 0.6666666666666666, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.1, 'mean_rec_rating': 7.94, 'std_rec_rating': 0.23748684174075832, 'min_rating': 7.6, 'max_rating': 8.5, 'rating_diff': 0.15999999999999925, 'unique_genres': 3, 'genre_entropy': 1.583143101527774, 'genre_distribution': {'Comedy': 9, 'Drama': 9, 'Romance': 10}}
# {'movie_title': 'Bãhubali: The Beginning', 'num_recommendations': 10, 'mean_genre_similarity': 0.7666666666666667, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.0, 'mean_rec_rating': 7.959999999999999, 'std_rec_rating': 0.27276363393971703, 'min_rating': 7.6, 'max_rating': 8.5, 'rating_diff': 0.040000000000000924, 'unique_genres': 4, 'genre_entropy': 1.6424239617719751, 'genre_distribution': {'Action': 8, 'Drama': 10, 'Crime': 3, 'Mystery': 1}}
# {'movie_title': 'Kaze tachinu', 'num_recommendations': 10, 'mean_genre_similarity': 0.4566666666666667, 'min_genre_similarity': 0.2, 'max_genre_similarity': 0.6666666666666666, 'input_movie_rating': 7.8, 'mean_rec_rating': 8.129999999999999, 'std_rec_rating': 0.36891733491393436, 'min_rating': 7.7, 'max_rating': 8.9, 'rating_diff': 0.3299999999999992, 'unique_genres': 10, 'genre_entropy': 2.7329584811468717, 'genre_distribution': {'Action': 2, 'Drama': 10, 'History': 3, 'Animation': 1, 'War': 2, 'Biography': 7, 'Music': 1, 'Romance': 1, 'Thriller': 1, 'Adventure': 1}}
# {'movie_title': 'The Blind Side', 'num_recommendations': 10, 'mean_genre_similarity': 0.8033333333333335, 'min_genre_similarity': 0.2, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.6, 'mean_rec_rating': 7.910000000000001, 'std_rec_rating': 0.2624880949681338, 'min_rating': 7.6, 'max_rating': 8.5, 'rating_diff': 0.3100000000000014, 'unique_genres': 5, 'genre_entropy': 1.9905418719405736, 'genre_distribution': {'Drama': 10, 'Sport': 7, 'Biography': 8, 'Comedy': 2, 'Family': 1}}
# {'movie_title': 'Soul', 'num_recommendations': 10, 'mean_genre_similarity': 1.0, 'min_genre_similarity': 1.0, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.1, 'mean_rec_rating': 8.079999999999998, 'std_rec_rating': 0.16, 'min_rating': 7.8, 'max_rating': 8.3, 'rating_diff': 0.02000000000000135, 'unique_genres': 3, 'genre_entropy': 1.584962500721156, 'genre_distribution': {'Animation': 10, 'Adventure': 10, 'Comedy': 10}}
# {'movie_title': 'Papillon', 'num_recommendations': 10, 'mean_genre_similarity': 0.7333333333333333, 'min_genre_similarity': 0.3333333333333333, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.0, 'mean_rec_rating': 7.989999999999999, 'std_rec_rating': 0.20223748416156692, 'min_rating': 7.6, 'max_rating': 8.4, 'rating_diff': 0.010000000000000675, 'unique_genres': 5, 'genre_entropy': 1.8906993328423072, 'genre_distribution': {'Crime': 8, 'Drama': 10, 'Biography': 5, 'Action': 1, 'Comedy': 1}}
# {'movie_title': 'Wind River', 'num_recommendations': 10, 'mean_genre_similarity': 0.85, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.7, 'mean_rec_rating': 7.9799999999999995, 'std_rec_rating': 0.3059411708155671, 'min_rating': 7.6, 'max_rating': 8.6, 'rating_diff': 0.27999999999999936, 'unique_genres': 6, 'genre_entropy': 2.0486037302133706, 'genre_distribution': {'Crime': 10, 'Drama': 9, 'Mystery': 8, 'Biography': 1, 'History': 1, 'Comedy': 1}}
# {'movie_title': 'The Game', 'num_recommendations': 10, 'mean_genre_similarity': 0.7366666666666667, 'min_genre_similarity': 0.2, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.8, 'mean_rec_rating': 8.03, 'std_rec_rating': 0.3034798181098704, 'min_rating': 7.6, 'max_rating': 8.6, 'rating_diff': 0.22999999999999954, 'unique_genres': 6, 'genre_entropy': 2.070418933233254, 'genre_distribution': {'Drama': 10, 'Mystery': 7, 'Action': 6, 'Thriller': 1, 'History': 1, 'War': 1}}
# {'movie_title': 'The Bourne Supremacy', 'num_recommendations': 10, 'mean_genre_similarity': 0.6416666666666667, 'min_genre_similarity': 0.25, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.7, 'mean_rec_rating': 7.99, 'std_rec_rating': 0.2700000000000002, 'min_rating': 7.6, 'max_rating': 8.4, 'rating_diff': 0.29000000000000004, 'unique_genres': 7, 'genre_entropy': 2.2303083326692295, 'genre_distribution': {'Action': 5, 'Mystery': 6, 'Thriller': 10, 'Adventure': 1, 'Drama': 1, 'Sci-Fi': 1, 'Romance': 1}}
# {'movie_title': 'Dangal', 'num_recommendations': 10, 'mean_genre_similarity': 0.7116666666666667, 'min_genre_similarity': 0.2, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.4, 'mean_rec_rating': 7.93, 'std_rec_rating': 0.21470910553583877, 'min_rating': 7.6, 'max_rating': 8.2, 'rating_diff': 0.47000000000000064, 'unique_genres': 6, 'genre_entropy': 2.22233562178604, 'genre_distribution': {'Drama': 10, 'Sport': 2, 'Action': 7, 'Adventure': 2, 'Comedy': 1, 'Biography': 6}}
# {'movie_title': 'Deadpool', 'num_recommendations': 10, 'mean_genre_similarity': 0.95, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.0, 'mean_rec_rating': 7.93, 'std_rec_rating': 0.20024984394500764, 'min_rating': 7.6, 'max_rating': 8.2, 'rating_diff': 0.07000000000000028, 'unique_genres': 4, 'genre_entropy': 1.7412943652509165, 'genre_distribution': {'Action': 9, 'Adventure': 10, 'Comedy': 10, 'Drama': 1}}
# {'movie_title': 'After Hours', 'num_recommendations': 10, 'mean_genre_similarity': 0.8666666666666666, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.7, 'mean_rec_rating': 8.05, 'std_rec_rating': 0.206155281280883, 'min_rating': 7.6, 'max_rating': 8.3, 'rating_diff': 0.35000000000000053, 'unique_genres': 5, 'genre_entropy': 1.9011325136843156, 'genre_distribution': {'Comedy': 9, 'Crime': 8, 'Drama': 10, 'Fantasy': 1, 'Action': 1}}
# {'movie_title': 'Raging Bull', 'num_recommendations': 10, 'mean_genre_similarity': 0.8, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.2, 'mean_rec_rating': 7.889999999999999, 'std_rec_rating': 0.19723082923316, 'min_rating': 7.6, 'max_rating': 8.2, 'rating_diff': 0.3100000000000005, 'unique_genres': 5, 'genre_entropy': 1.9078221168569185, 'genre_distribution': {'Drama': 10, 'Sport': 7, 'Biography': 8, 'Music': 1, 'Crime': 1}}
# {'movie_title': 'Kahaani', 'num_recommendations': 10, 'mean_genre_similarity': 0.8666666666666666, 'min_genre_similarity': 0.6666666666666666, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.1, 'mean_rec_rating': 7.970000000000001, 'std_rec_rating': 0.3579106033634658, 'min_rating': 7.6, 'max_rating': 8.5, 'rating_diff': 0.129999999999999, 'unique_genres': 5, 'genre_entropy': 1.7333557549816876, 'genre_distribution': {'Mystery': 10, 'Thriller': 10, 'Sci-Fi': 1, 'Drama': 1, 'Crime': 2}}
# {'movie_title': 'Lord of War', 'num_recommendations': 10, 'mean_genre_similarity': 0.95, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.6, 'mean_rec_rating': 8.149999999999999, 'std_rec_rating': 0.393064880140671, 'min_rating': 7.6, 'max_rating': 9.0, 'rating_diff': 0.5499999999999989, 'unique_genres': 4, 'genre_entropy': 1.7412943652509165, 'genre_distribution': {'Action': 9, 'Crime': 10, 'Drama': 10, 'Mystery': 1}}
# {'movie_title': 'Queen', 'num_recommendations': 10, 'mean_genre_similarity': 0.6166666666666666, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.2, 'mean_rec_rating': 8.02, 'std_rec_rating': 0.22271057451320078, 'min_rating': 7.6, 'max_rating': 8.5, 'rating_diff': 0.17999999999999972, 'unique_genres': 8, 'genre_entropy': 2.482330892038569, 'genre_distribution': {'Action': 3, 'Adventure': 5, 'Comedy': 9, 'Drama': 8, 'Romance': 1, 'Musical': 1, 'Music': 1, 'Crime': 1}}
# {'movie_title': 'Jaws', 'num_recommendations': 10, 'mean_genre_similarity': 0.6666666666666667, 'min_genre_similarity': 0.6666666666666666, 'max_genre_similarity': 0.6666666666666666, 'input_movie_rating': 8.0, 'mean_rec_rating': 7.909999999999999, 'std_rec_rating': 0.25079872407968923, 'min_rating': 7.6, 'max_rating': 8.3, 'rating_diff': 0.09000000000000075, 'unique_genres': 5, 'genre_entropy': 2.038617183202383, 'genre_distribution': {'Action': 5, 'Adventure': 10, 'Thriller': 10, 'Drama': 4, 'Mystery': 1}}
# {'movie_title': 'Philomena', 'num_recommendations': 10, 'mean_genre_similarity': 0.7333333333333333, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.6, 'mean_rec_rating': 8.0, 'std_rec_rating': 0.23237900077244503, 'min_rating': 7.6, 'max_rating': 8.5, 'rating_diff': 0.40000000000000036, 'unique_genres': 5, 'genre_entropy': 1.9086345734705732, 'genre_distribution': {'Comedy': 6, 'Drama': 10, 'Biography': 7, 'Family': 1, 'Sport': 1}}
# {'movie_title': 'Star Wars: Episode V - The Empire Strikes Back', 'num_recommendations': 10, 'mean_genre_similarity': 0.7666666666666666, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.7, 'mean_rec_rating': 7.989999999999999, 'std_rec_rating': 0.2947880594596735, 'min_rating': 7.6, 'max_rating': 8.6, 'rating_diff': 0.71, 'unique_genres': 6, 'genre_entropy': 2.1249333756040762, 'genre_distribution': {'Action': 10, 'Adventure': 9, 'Fantasy': 6, 'Animation': 2, 'Sci-Fi': 1, 'Family': 1}}
# {'movie_title': 'This Is Spinal Tap', 'num_recommendations': 10, 'mean_genre_similarity': 0.5833333333333333, 'min_genre_similarity': 0.3333333333333333, 'max_genre_similarity': 0.6666666666666666, 'input_movie_rating': 7.9, 'mean_rec_rating': 7.95, 'std_rec_rating': 0.233452350598575, 'min_rating': 7.6, 'max_rating': 8.4, 'rating_diff': 0.04999999999999982, 'unique_genres': 5, 'genre_entropy': 1.9701247407004667, 'genre_distribution': {'Comedy': 10, 'Drama': 4, 'Music': 6, 'Romance': 1, 'Musical': 2}}
# {'movie_title': 'Moana', 'num_recommendations': 10, 'mean_genre_similarity': 0.9, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.6, 'mean_rec_rating': 8.0, 'std_rec_rating': 0.2190890230020664, 'min_rating': 7.6, 'max_rating': 8.3, 'rating_diff': 0.40000000000000036, 'unique_genres': 5, 'genre_entropy': 1.897626229780677, 'genre_distribution': {'Animation': 9, 'Adventure': 10, 'Comedy': 9, 'Family': 1, 'Drama': 1}}
# {'movie_title': 'Bajrangi Bhaijaan', 'num_recommendations': 10, 'mean_genre_similarity': 0.8, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.0, 'mean_rec_rating': 7.88, 'std_rec_rating': 0.23151673805580436, 'min_rating': 7.6, 'max_rating': 8.2, 'rating_diff': 0.1200000000000001, 'unique_genres': 5, 'genre_entropy': 2.0602209150665964, 'genre_distribution': {'Action': 7, 'Adventure': 10, 'Comedy': 9, 'Animation': 2, 'Drama': 2}}
# {'movie_title': 'Blade Runner 2049', 'num_recommendations': 10, 'mean_genre_similarity': 0.645, 'min_genre_similarity': 0.2, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.0, 'mean_rec_rating': 8.01, 'std_rec_rating': 0.34481879299133344, 'min_rating': 7.6, 'max_rating': 8.6, 'rating_diff': 0.009999999999999787, 'unique_genres': 6, 'genre_entropy': 2.318369254032932, 'genre_distribution': {'Action': 5, 'Sci-Fi': 1, 'Thriller': 3, 'Drama': 9, 'Mystery': 8, 'Crime': 3}}
# {'movie_title': 'Il postino', 'num_recommendations': 10, 'mean_genre_similarity': 0.8, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.7, 'mean_rec_rating': 7.95, 'std_rec_rating': 0.23345235059857494, 'min_rating': 7.7, 'max_rating': 8.5, 'rating_diff': 0.25, 'unique_genres': 5, 'genre_entropy': 1.9078221168569185, 'genre_distribution': {'Comedy': 8, 'Drama': 10, 'Family': 1, 'Biography': 7, 'Romance': 1}}
# {'movie_title': 'Repulsion', 'num_recommendations': 10, 'mean_genre_similarity': 0.7, 'min_genre_similarity': 0.3333333333333333, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.7, 'mean_rec_rating': 7.909999999999999, 'std_rec_rating': 0.26627053911388693, 'min_rating': 7.6, 'max_rating': 8.4, 'rating_diff': 0.20999999999999908, 'unique_genres': 5, 'genre_entropy': 1.898278922483087, 'genre_distribution': {'Drama': 10, 'Horror': 5, 'Thriller': 7, 'Mystery': 1, 'Crime': 1}}
# {'movie_title': 'Sleuth', 'num_recommendations': 10, 'mean_genre_similarity': 0.9, 'min_genre_similarity': 0.6666666666666666, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.0, 'mean_rec_rating': 8.03, 'std_rec_rating': 0.31320919526731666, 'min_rating': 7.6, 'max_rating': 8.4, 'rating_diff': 0.02999999999999936, 'unique_genres': 4, 'genre_entropy': 1.547972308328872, 'genre_distribution': {'Mystery': 10, 'Thriller': 10, 'Drama': 2, 'Horror': 1}}
# {'movie_title': 'Viskningar och rop', 'num_recommendations': 10, 'mean_genre_similarity': 0.9333333333333332, 'min_genre_similarity': 0.3333333333333333, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.1, 'mean_rec_rating': 7.88, 'std_rec_rating': 0.21817424229271432, 'min_rating': 7.6, 'max_rating': 8.3, 'rating_diff': 0.21999999999999975, 'unique_genres': 3, 'genre_entropy': 0.8166890883150209, 'genre_distribution': {'Drama': 10, 'Comedy': 1, 'Romance': 1}}
# {'movie_title': 'Ah-ga-ssi', 'num_recommendations': 10, 'mean_genre_similarity': 0.6333333333333333, 'min_genre_similarity': 0.3333333333333333, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.1, 'mean_rec_rating': 7.859999999999999, 'std_rec_rating': 0.18547236990991392, 'min_rating': 7.6, 'max_rating': 8.2, 'rating_diff': 0.2400000000000002, 'unique_genres': 5, 'genre_entropy': 1.8400837592991006, 'genre_distribution': {'Drama': 10, 'Romance': 7, 'Mystery': 1, 'Thriller': 3, 'Film-Noir': 1}}
# {'movie_title': 'Lucky Number Slevin', 'num_recommendations': 10, 'mean_genre_similarity': 0.9, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.7, 'mean_rec_rating': 7.88, 'std_rec_rating': 0.2638181191654584, 'min_rating': 7.6, 'max_rating': 8.5, 'rating_diff': 0.17999999999999972, 'unique_genres': 5, 'genre_entropy': 1.897626229780677, 'genre_distribution': {'Action': 9, 'Crime': 10, 'Drama': 9, 'Animation': 1, 'Comedy': 1}}
# {'movie_title': 'Paan Singh Tomar', 'num_recommendations': 10, 'mean_genre_similarity': 0.5700000000000001, 'min_genre_similarity': 0.2, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.2, 'mean_rec_rating': 7.909999999999999, 'std_rec_rating': 0.30149626863362683, 'min_rating': 7.6, 'max_rating': 8.5, 'rating_diff': 0.29000000000000004, 'unique_genres': 6, 'genre_entropy': 2.2797991318374056, 'genre_distribution': {'Action': 8, 'Biography': 7, 'Crime': 6, 'Drama': 7, 'Sport': 1, 'Thriller': 1}}
# {'movie_title': 'Gladiator', 'num_recommendations': 10, 'mean_genre_similarity': 0.5366666666666666, 'min_genre_similarity': 0.2, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.5, 'mean_rec_rating': 8.03, 'std_rec_rating': 0.2410394158638788, 'min_rating': 7.7, 'max_rating': 8.5, 'rating_diff': 0.47000000000000064, 'unique_genres': 7, 'genre_entropy': 2.568200719475571, 'genre_distribution': {'Adventure': 6, 'Drama': 9, 'History': 2, 'Action': 5, 'Crime': 3, 'Comedy': 2, 'Biography': 2}}
# {'movie_title': 'Detachment', 'num_recommendations': 10, 'mean_genre_similarity': 0.85, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.7, 'mean_rec_rating': 7.979999999999999, 'std_rec_rating': 0.19899748742132406, 'min_rating': 7.6, 'max_rating': 8.3, 'rating_diff': 0.2799999999999985, 'unique_genres': 4, 'genre_entropy': 1.1451104143815827, 'genre_distribution': {'Drama': 10, 'Comedy': 1, 'Music': 1, 'Thriller': 1}}
# {'movie_title': 'Fear and Loathing in Las Vegas', 'num_recommendations': 10, 'mean_genre_similarity': 0.8166666666666667, 'min_genre_similarity': 0.3333333333333333, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.6, 'mean_rec_rating': 7.95, 'std_rec_rating': 0.29410882339705463, 'min_rating': 7.6, 'max_rating': 8.6, 'rating_diff': 0.35000000000000053, 'unique_genres': 4, 'genre_entropy': 1.7500499304347517, 'genre_distribution': {'Comedy': 9, 'Drama': 9, 'Adventure': 7, 'Sci-Fi': 1}}
# {'movie_title': 'Stalker', 'num_recommendations': 10, 'mean_genre_similarity': 0.775, 'min_genre_similarity': 0.25, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.2, 'mean_rec_rating': 8.05, 'std_rec_rating': 0.47381430961928556, 'min_rating': 7.6, 'max_rating': 9.3, 'rating_diff': 0.14999999999999858, 'unique_genres': 6, 'genre_entropy': 1.9488106104538123, 'genre_distribution': {'Action': 2, 'Drama': 10, 'Sci-Fi': 8, 'Mystery': 1, 'Romance': 1, 'Horror': 1}}
# {'movie_title': 'The Artist', 'num_recommendations': 10, 'mean_genre_similarity': 0.675, 'min_genre_similarity': 0.25, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.9, 'mean_rec_rating': 7.880000000000001, 'std_rec_rating': 0.2821347195933178, 'min_rating': 7.6, 'max_rating': 8.4, 'rating_diff': 0.019999999999999574, 'unique_genres': 7, 'genre_entropy': 2.250801853844516, 'genre_distribution': {'Drama': 9, 'Film-Noir': 1, 'Comedy': 6, 'Musical': 1, 'Romance': 7, 'Sci-Fi': 1, 'Music': 1}}
# {'movie_title': 'Nelyubov', 'num_recommendations': 10, 'mean_genre_similarity': 1.0, 'min_genre_similarity': 1.0, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.6, 'mean_rec_rating': 8.05, 'std_rec_rating': 0.2941088233970551, 'min_rating': 7.6, 'max_rating': 8.5, 'rating_diff': 0.45000000000000107, 'unique_genres': 1, 'genre_entropy': -0.0, 'genre_distribution': {'Drama': 10}}
# ...
# {'movie_title': 'Mad Max 2', 'num_recommendations': 10, 'mean_genre_similarity': 0.85, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.6, 'mean_rec_rating': 8.180000000000001, 'std_rec_rating': 0.3249615361854385, 'min_rating': 7.7, 'max_rating': 8.8, 'rating_diff': 0.5800000000000018, 'unique_genres': 5, 'genre_entropy': 1.9819370635467042, 'genre_distribution': {'Action': 9, 'Adventure': 10, 'Sci-Fi': 8, 'Drama': 2, 'Western': 1}}
# {'movie_title': 'Kaguyahime no monogatari', 'num_recommendations': 10, 'mean_genre_similarity': 0.8166666666666667, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.0, 'mean_rec_rating': 7.99, 'std_rec_rating': 0.28442925306655786, 'min_rating': 7.6, 'max_rating': 8.5, 'rating_diff': 0.009999999999999787, 'unique_genres': 6, 'genre_entropy': 2.0628551321633783, 'genre_distribution': {'Animation': 9, 'Adventure': 9, 'Drama': 8, 'Family': 1, 'Biography': 1, 'Comedy': 1}}
# {'movie_title': 'Kumonosu-jô', 'num_recommendations': 10, 'mean_genre_similarity': 0.6083333333333333, 'min_genre_similarity': 0.25, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.1, 'mean_rec_rating': 7.9799999999999995, 'std_rec_rating': 0.15362291495737232, 'min_rating': 7.8, 'max_rating': 8.3, 'rating_diff': 0.1200000000000001, 'unique_genres': 6, 'genre_entropy': 2.0311836644228602, 'genre_distribution': {'Drama': 10, 'History': 5, 'Romance': 1, 'Sport': 1, 'Biography': 3, 'Comedy': 1}}
# {'movie_title': 'La dolce vita', 'num_recommendations': 10, 'mean_genre_similarity': 0.7833333333333333, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.0, 'mean_rec_rating': 7.93, 'std_rec_rating': 0.19, 'min_rating': 7.6, 'max_rating': 8.1, 'rating_diff': 0.07000000000000028, 'unique_genres': 7, 'genre_entropy': 2.0121039189772216, 'genre_distribution': {'Comedy': 9, 'Drama': 10, 'Adventure': 1, 'Thriller': 1, 'Animation': 1, 'Family': 1, 'Biography': 1}}
# {'movie_title': 'The Illusionist', 'num_recommendations': 10, 'mean_genre_similarity': 0.49499999999999994, 'min_genre_similarity': 0.2, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.6, 'mean_rec_rating': 8.04, 'std_rec_rating': 0.21999999999999978, 'min_rating': 7.8, 'max_rating': 8.6, 'rating_diff': 0.4399999999999995, 'unique_genres': 8, 'genre_entropy': 2.5929786596998916, 'genre_distribution': {'Drama': 9, 'Film-Noir': 2, 'Mystery': 6, 'Fantasy': 3, 'Horror': 1, 'Romance': 2, 'Music': 2, 'Crime': 1}}
# {'movie_title': 'Barton Fink', 'num_recommendations': 10, 'mean_genre_similarity': 0.5999999999999999, 'min_genre_similarity': 0.3333333333333333, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.7, 'mean_rec_rating': 7.95, 'std_rec_rating': 0.28722813232690136, 'min_rating': 7.6, 'max_rating': 8.6, 'rating_diff': 0.25, 'unique_genres': 7, 'genre_entropy': 2.221251836004466, 'genre_distribution': {'Comedy': 6, 'Drama': 10, 'Horror': 1, 'Thriller': 4, 'History': 1, 'Romance': 1, 'Adventure': 1}}
# {'movie_title': 'Spartacus', 'num_recommendations': 10, 'mean_genre_similarity': 0.725, 'min_genre_similarity': 0.25, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.9, 'mean_rec_rating': 8.060000000000002, 'std_rec_rating': 0.2576819745345026, 'min_rating': 7.7, 'max_rating': 8.5, 'rating_diff': 0.16000000000000192, 'unique_genres': 7, 'genre_entropy': 2.281116996741346, 'genre_distribution': {'Action': 1, 'Adventure': 8, 'Drama': 10, 'History': 2, 'Biography': 6, 'Western': 1, 'Fantasy': 1}}
# {'movie_title': 'In the Name of the Father', 'num_recommendations': 10, 'mean_genre_similarity': 0.7833333333333333, 'min_genre_similarity': 0.3333333333333333, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.1, 'mean_rec_rating': 7.9399999999999995, 'std_rec_rating': 0.35832945734337823, 'min_rating': 7.6, 'max_rating': 8.7, 'rating_diff': 0.16000000000000014, 'unique_genres': 4, 'genre_entropy': 1.7095263323230747, 'genre_distribution': {'Biography': 5, 'Crime': 9, 'Drama': 10, 'Action': 1}}
# {'movie_title': 'Zelig', 'num_recommendations': 10, 'mean_genre_similarity': 0.8333333333333333, 'min_genre_similarity': 0.3333333333333333, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.7, 'mean_rec_rating': 7.88, 'std_rec_rating': 0.227156333832011, 'min_rating': 7.6, 'max_rating': 8.4, 'rating_diff': 0.17999999999999972, 'unique_genres': 4, 'genre_entropy': 1.2916919971380594, 'genre_distribution': {'Comedy': 10, 'Animation': 1, 'Adventure': 1, 'Drama': 2}}
# {'movie_title': 'The Hobbit: The Desolation of Smaug', 'num_recommendations': 10, 'mean_genre_similarity': 0.6583333333333334, 'min_genre_similarity': 0.25, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.8, 'mean_rec_rating': 8.129999999999999, 'std_rec_rating': 0.4450842616853578, 'min_rating': 7.6, 'max_rating': 8.9, 'rating_diff': 0.3299999999999992, 'unique_genres': 5, 'genre_entropy': 2.0525242214623565, 'genre_distribution': {'Adventure': 10, 'Fantasy': 9, 'Family': 4, 'Action': 5, 'Drama': 1}}
# {'movie_title': 'Tôkyô goddofâzâzu', 'num_recommendations': 10, 'mean_genre_similarity': 0.9, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.8, 'mean_rec_rating': 7.99, 'std_rec_rating': 0.22999999999999993, 'min_rating': 7.6, 'max_rating': 8.3, 'rating_diff': 0.1900000000000004, 'unique_genres': 5, 'genre_entropy': 1.897626229780677, 'genre_distribution': {'Adventure': 9, 'Comedy': 10, 'Family': 1, 'Animation': 9, 'Drama': 1}}
# {'movie_title': 'The Invisible Man', 'num_recommendations': 10, 'mean_genre_similarity': 0.45, 'min_genre_similarity': 0.0, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.7, 'mean_rec_rating': 7.94, 'std_rec_rating': 0.2107130750570549, 'min_rating': 7.6, 'max_rating': 8.4, 'rating_diff': 0.2400000000000002, 'unique_genres': 9, 'genre_entropy': 2.755844226199132, 'genre_distribution': {'Drama': 5, 'Horror': 5, 'Sci-Fi': 8, 'Thriller': 1, 'Adventure': 3, 'Action': 1, 'Comedy': 1, 'Fantasy': 1, 'Mystery': 2}}
# {'movie_title': 'Philadelphia', 'num_recommendations': 10, 'mean_genre_similarity': 0.8666666666666666, 'min_genre_similarity': 0.3333333333333333, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.7, 'mean_rec_rating': 7.859999999999999, 'std_rec_rating': 0.27640549922170504, 'min_rating': 7.6, 'max_rating': 8.5, 'rating_diff': 0.15999999999999925, 'unique_genres': 5, 'genre_entropy': 1.4345491399952024, 'genre_distribution': {'Drama': 10, 'Crime': 1, 'Mystery': 1, 'Biography': 1, 'Comedy': 1}}
# {'movie_title': 'Un long dimanche de fiançailles', 'num_recommendations': 10, 'mean_genre_similarity': 0.6, 'min_genre_similarity': 0.3333333333333333, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.6, 'mean_rec_rating': 7.909999999999999, 'std_rec_rating': 0.19723082923316, 'min_rating': 7.6, 'max_rating': 8.2, 'rating_diff': 0.3099999999999996, 'unique_genres': 6, 'genre_entropy': 2.1379185026711327, 'genre_distribution': {'Drama': 10, 'Fantasy': 1, 'Romance': 6, 'Mystery': 4, 'Comedy': 1, 'Crime': 2}}
# {'movie_title': 'Jodaeiye Nader az Simin', 'num_recommendations': 10, 'mean_genre_similarity': 0.9, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.3, 'mean_rec_rating': 7.8, 'std_rec_rating': 0.18973665961010275, 'min_rating': 7.6, 'max_rating': 8.2, 'rating_diff': 0.5000000000000009, 'unique_genres': 3, 'genre_entropy': 0.8166890883150209, 'genre_distribution': {'Drama': 10, 'Comedy': 1, 'War': 1}}
# {'movie_title': 'Alien', 'num_recommendations': 10, 'mean_genre_similarity': 0.6, 'min_genre_similarity': 0.25, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.4, 'mean_rec_rating': 7.87, 'std_rec_rating': 0.200249843945008, 'min_rating': 7.6, 'max_rating': 8.3, 'rating_diff': 0.5300000000000002, 'unique_genres': 6, 'genre_entropy': 2.262879631232199, 'genre_distribution': {'Horror': 8, 'Sci-Fi': 9, 'Adventure': 3, 'Drama': 4, 'Action': 2, 'Mystery': 1}}
# {'movie_title': 'American Beauty', 'num_recommendations': 10, 'mean_genre_similarity': 0.8, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.3, 'mean_rec_rating': 7.909999999999999, 'std_rec_rating': 0.2256102834535696, 'min_rating': 7.6, 'max_rating': 8.4, 'rating_diff': 0.39000000000000146, 'unique_genres': 5, 'genre_entropy': 1.4345491399952024, 'genre_distribution': {'Drama': 10, 'Musical': 1, 'Mystery': 1, 'Romance': 1, 'Comedy': 1}}
# {'movie_title': 'Ikiru', 'num_recommendations': 10, 'mean_genre_similarity': 0.9, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.3, 'mean_rec_rating': 7.970000000000001, 'std_rec_rating': 0.22383029285599382, 'min_rating': 7.7, 'max_rating': 8.5, 'rating_diff': 0.33000000000000007, 'unique_genres': 3, 'genre_entropy': 0.8166890883150209, 'genre_distribution': {'Drama': 10, 'Sci-Fi': 1, 'Thriller': 1}}
# {'movie_title': 'Naked', 'num_recommendations': 10, 'mean_genre_similarity': 0.725, 'min_genre_similarity': 0.25, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.8, 'mean_rec_rating': 7.9, 'std_rec_rating': 0.18439088914585777, 'min_rating': 7.6, 'max_rating': 8.1, 'rating_diff': 0.10000000000000053, 'unique_genres': 6, 'genre_entropy': 1.9653059184883492, 'genre_distribution': {'Comedy': 7, 'Drama': 10, 'Fantasy': 1, 'Music': 1, 'Romance': 1, 'Crime': 2}}
# {'movie_title': 'Kramer vs. Kramer', 'num_recommendations': 10, 'mean_genre_similarity': 1.0, 'min_genre_similarity': 1.0, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.8, 'mean_rec_rating': 7.87, 'std_rec_rating': 0.2685144316419513, 'min_rating': 7.6, 'max_rating': 8.3, 'rating_diff': 0.07000000000000028, 'unique_genres': 1, 'genre_entropy': -0.0, 'genre_distribution': {'Drama': 10}}
# {'movie_title': 'American Gangster', 'num_recommendations': 10, 'mean_genre_similarity': 0.6666666666666666, 'min_genre_similarity': 0.3333333333333333, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.8, 'mean_rec_rating': 8.0, 'std_rec_rating': 0.3898717737923586, 'min_rating': 7.6, 'max_rating': 9.0, 'rating_diff': 0.20000000000000018, 'unique_genres': 5, 'genre_entropy': 1.877006938523237, 'genre_distribution': {'Biography': 4, 'Crime': 7, 'Drama': 10, 'Action': 1, 'Film-Noir': 1}}
# {'movie_title': 'Ace in the Hole', 'num_recommendations': 10, 'mean_genre_similarity': 0.7, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.1, 'mean_rec_rating': 7.989999999999999, 'std_rec_rating': 0.2211334438749599, 'min_rating': 7.7, 'max_rating': 8.4, 'rating_diff': 0.11000000000000032, 'unique_genres': 4, 'genre_entropy': 1.5779772001172403, 'genre_distribution': {'Drama': 10, 'Film-Noir': 6, 'Romance': 1, 'Crime': 2}}
# {'movie_title': 'The Wolf of Wall Street', 'num_recommendations': 10, 'mean_genre_similarity': 0.7833333333333333, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.2, 'mean_rec_rating': 7.92, 'std_rec_rating': 0.31559467676118985, 'min_rating': 7.6, 'max_rating': 8.7, 'rating_diff': 0.27999999999999936, 'unique_genres': 6, 'genre_entropy': 2.061970443369145, 'genre_distribution': {'Action': 1, 'Biography': 7, 'Drama': 10, 'Crime': 8, 'Sport': 1, 'Thriller': 1}}
# {'movie_title': 'Lagaan: Once Upon a Time in India', 'num_recommendations': 10, 'mean_genre_similarity': 0.45, 'min_genre_similarity': 0.25, 'max_genre_similarity': 0.6666666666666666, 'input_movie_rating': 8.1, 'mean_rec_rating': 7.909999999999999, 'std_rec_rating': 0.2773084924772408, 'min_rating': 7.6, 'max_rating': 8.6, 'rating_diff': 0.1900000000000004, 'unique_genres': 9, 'genre_entropy': 2.5044984515601634, 'genre_distribution': {'Comedy': 1, 'Drama': 10, 'Sport': 1, 'Adventure': 6, 'Action': 3, 'Family': 1, 'Musical': 1, 'Thriller': 1, 'Western': 1}}
# {'movie_title': 'Gone with the Wind', 'num_recommendations': 10, 'mean_genre_similarity': 0.6200000000000001, 'min_genre_similarity': 0.2, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.1, 'mean_rec_rating': 7.9799999999999995, 'std_rec_rating': 0.1777638883463118, 'min_rating': 7.7, 'max_rating': 8.3, 'rating_diff': 0.1200000000000001, 'unique_genres': 7, 'genre_entropy': 2.117492461184755, 'genre_distribution': {'Drama': 10, 'Romance': 8, 'Biography': 1, 'History': 2, 'Comedy': 1, 'Adventure': 1, 'Western': 1}}
# {'movie_title': 'Nueve reinas', 'num_recommendations': 10, 'mean_genre_similarity': 0.9, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.9, 'mean_rec_rating': 8.22, 'std_rec_rating': 0.2891366458960193, 'min_rating': 7.6, 'max_rating': 8.6, 'rating_diff': 0.3200000000000003, 'unique_genres': 4, 'genre_entropy': 1.8256051990169437, 'genre_distribution': {'Comedy': 2, 'Crime': 10, 'Drama': 10, 'Thriller': 8}}
# {'movie_title': 'No Country for Old Men', 'num_recommendations': 10, 'mean_genre_similarity': 0.8, 'min_genre_similarity': 0.5, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.1, 'mean_rec_rating': 8.1, 'std_rec_rating': 0.40000000000000013, 'min_rating': 7.6, 'max_rating': 8.9, 'rating_diff': 0.0, 'unique_genres': 5, 'genre_entropy': 1.8642133402307257, 'genre_distribution': {'Crime': 10, 'Drama': 10, 'Thriller': 5, 'Action': 1, 'Comedy': 1}}
# {'movie_title': 'Zwartboek', 'num_recommendations': 10, 'mean_genre_similarity': 0.62, 'min_genre_similarity': 0.2, 'max_genre_similarity': 1.0, 'input_movie_rating': 7.7, 'mean_rec_rating': 8.139999999999999, 'std_rec_rating': 0.2727636339397173, 'min_rating': 7.6, 'max_rating': 8.5, 'rating_diff': 0.4399999999999986, 'unique_genres': 8, 'genre_entropy': 2.319753948020712, 'genre_distribution': {'Drama': 10, 'Thriller': 2, 'War': 9, 'Adventure': 1, 'Animation': 1, 'Biography': 2, 'Music': 1, 'Romance': 1}}
# {'movie_title': 'The Graduate', 'num_recommendations': 10, 'mean_genre_similarity': 0.7, 'min_genre_similarity': 0.3333333333333333, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.0, 'mean_rec_rating': 7.889999999999999, 'std_rec_rating': 0.15132745950421553, 'min_rating': 7.6, 'max_rating': 8.1, 'rating_diff': 0.11000000000000121, 'unique_genres': 5, 'genre_entropy': 1.898278922483087, 'genre_distribution': {'Comedy': 5, 'Drama': 10, 'Romance': 7, 'Mystery': 1, 'Music': 1}}
# {'movie_title': 'Zindagi Na Milegi Dobara', 'num_recommendations': 10, 'mean_genre_similarity': 0.7416666666666667, 'min_genre_similarity': 0.25, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.1, 'mean_rec_rating': 7.969999999999999, 'std_rec_rating': 0.2368543856465402, 'min_rating': 7.6, 'max_rating': 8.4, 'rating_diff': 0.13000000000000078, 'unique_genres': 6, 'genre_entropy': 1.9808259362290785, 'genre_distribution': {'Comedy': 8, 'Drama': 9, 'Adventure': 1, 'Crime': 1, 'Mystery': 1, 'Romance': 2}}
# {'movie_title': 'The Wizard of Oz', 'num_recommendations': 10, 'mean_genre_similarity': 0.7666666666666666, 'min_genre_similarity': 0.25, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.0, 'mean_rec_rating': 7.8, 'std_rec_rating': 0.15491933384829668, 'min_rating': 7.6, 'max_rating': 8.1, 'rating_diff': 0.20000000000000018, 'unique_genres': 6, 'genre_entropy': 2.0882208354968017, 'genre_distribution': {'Adventure': 8, 'Family': 8, 'Fantasy': 8, 'Comedy': 1, 'Sci-Fi': 1, 'Drama': 1}}
# {'movie_title': "Hachi: A Dog's Tale", 'num_recommendations': 10, 'mean_genre_similarity': 0.5666666666666667, 'min_genre_similarity': 0.3333333333333333, 'max_genre_similarity': 1.0, 'input_movie_rating': 8.1, 'mean_rec_rating': 7.94, 'std_rec_rating': 0.2154065922853803, 'min_rating': 7.6, 'max_rating': 8.3, 'rating_diff': 0.15999999999999925, 'unique_genres': 7, 'genre_entropy': 2.1981731101716204, 'genre_distribution': {'Drama': 10, 'Comedy': 1, 'Family': 3, 'Biography': 6, 'Adventure': 1, 'Crime': 1, 'Musical': 1}}
